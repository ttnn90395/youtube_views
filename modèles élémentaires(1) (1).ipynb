# %% [markdown]
# Importation des données

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


data_path = "/kaggle/input/CSC_43M04_EP_challenge/dataset"

train_df = pd.read_csv(f"{data_path}/train_val.csv")
test_df = pd.read_csv(f"{data_path}/test.csv")

def get_image_path(img_id, is_test=False):
    folder = "test" if is_test else "train_val"
    return os.path.join(data_path, folder, f"{img_id}.jpg")
# Out:
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val.csv
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test.csv
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1269.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/623.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2193.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2008.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2081.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3138.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/764.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1700.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1786.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2907.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1075.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2863.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/771.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/208.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2628.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3363.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/820.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3228.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1789.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/473.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1792.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2936.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2029.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1411.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1031.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1833.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2675.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2172.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1749.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1501.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2021.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1995.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1385.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2278.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1971.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1383.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/333.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1354.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1024.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/537.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3014.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/45.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2375.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/369.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1626.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/56.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/654.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/89.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1711.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/20.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1339.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/275.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2532.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1161.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/785.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2262.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2213.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1940.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1777.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1380.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/212.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/239.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/792.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2057.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1009.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3295.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2094.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1157.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/58.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2302.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2695.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1304.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1340.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1760.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2028.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1173.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1790.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/150.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2137.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/6.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3364.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/109.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2654.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1650.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1211.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3310.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3209.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2319.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/149.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1488.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1862.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1167.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1644.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1539.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2640.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/187.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/521.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/436.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/76.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/539.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3330.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2844.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1355.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/355.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2899.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2041.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1565.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/516.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1409.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/71.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/708.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1222.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1154.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/474.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1840.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3207.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2580.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3280.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1124.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/501.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1395.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2363.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/915.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/815.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/760.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/342.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1459.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2704.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/817.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2003.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/429.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2000.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1055.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2560.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/646.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2753.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/682.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1548.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3198.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3322.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1934.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/544.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1794.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1715.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2953.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2279.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/377.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1026.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2866.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/272.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/795.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/270.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3221.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/182.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2182.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1936.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1162.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3195.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/215.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2067.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2558.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/489.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/576.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2571.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1834.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2749.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2397.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2526.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/185.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1484.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3064.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2751.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1920.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/613.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/930.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/243.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2748.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1702.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2510.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3366.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1010.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/153.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2743.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/703.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2852.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1451.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/189.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/143.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2719.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2486.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1025.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2444.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3085.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1343.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1579.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1774.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3347.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/476.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2403.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2626.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2982.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/717.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2716.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3260.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3382.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1473.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/327.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2178.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1669.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/253.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2673.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/343.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1815.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2643.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1746.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2271.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/115.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2517.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1905.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/131.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2087.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1058.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/446.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1498.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1166.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1812.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1601.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3010.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/626.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1443.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2174.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2997.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3323.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2150.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2394.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/425.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/5.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1559.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/824.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/366.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2809.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2530.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2922.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1101.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/850.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2897.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/885.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2789.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1327.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1781.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3318.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/151.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1097.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2552.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3011.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1376.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2655.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3164.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/426.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2204.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/732.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/503.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2573.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1297.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/8.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2011.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/641.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/892.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2131.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1478.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2471.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1413.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1604.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2476.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2984.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2928.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2470.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2608.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2595.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/988.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/622.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1129.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2501.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2323.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2627.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1655.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2795.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1144.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/440.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/260.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1716.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3037.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3305.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3284.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3243.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2282.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/534.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3395.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3302.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/202.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/84.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/577.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/751.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2698.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/944.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/237.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/273.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/286.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1032.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3218.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/283.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/486.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2338.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/513.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/766.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2460.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/85.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2902.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/564.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/359.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3058.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/67.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1709.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2998.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2725.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2625.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/265.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2505.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/289.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2020.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1125.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1331.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3242.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2587.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3298.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2457.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2537.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2633.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/973.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3358.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3114.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1424.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3303.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3377.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/118.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2842.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2186.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3288.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3030.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1037.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/950.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/768.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/361.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1089.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1136.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/591.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2091.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3394.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3179.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2890.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1171.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/82.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1387.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2564.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1744.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1391.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1795.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/723.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2475.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3016.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3109.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2555.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/443.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/295.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2596.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3215.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2168.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1134.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/176.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3119.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1389.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1475.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2237.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1554.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2139.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1243.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3017.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3122.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1499.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2993.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/279.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2782.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/668.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2812.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/757.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2681.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2718.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/30.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/97.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2417.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1002.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/334.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/106.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2391.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1172.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2980.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1527.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/806.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2696.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2874.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2183.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/163.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2386.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/113.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2500.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1845.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3264.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/160.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/518.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/994.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/38.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2228.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2033.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1401.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/463.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/349.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/490.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/328.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2592.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2964.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/211.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1041.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/829.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/788.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/811.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1196.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3110.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3387.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2214.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/978.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2232.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1312.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2495.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3117.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2694.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1648.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/863.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2878.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/42.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/291.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/949.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2089.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1778.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1071.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1575.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2503.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1336.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2840.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2869.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3141.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3202.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2703.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1569.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2270.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2515.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1680.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/197.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1019.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/704.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2981.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/630.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/33.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/10.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/234.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2974.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/818.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2451.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1727.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/178.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/54.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/990.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3142.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2642.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2688.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/672.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/271.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/683.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/251.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2196.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2784.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/759.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/665.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2645.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1371.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2431.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/0.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/130.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1168.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/62.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/916.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2925.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2035.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1677.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/833.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3331.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1076.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1183.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2900.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/948.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3257.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1268.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1603.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2661.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2079.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2312.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/951.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/589.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/278.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/743.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/500.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2211.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1660.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/156.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1755.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2624.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/380.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/558.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1118.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2125.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/120.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2159.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/998.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1592.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2683.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3384.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2113.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1108.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1571.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/456.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2332.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2616.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/35.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2097.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2286.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/629.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1018.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/290.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2952.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/61.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2944.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3333.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3066.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2512.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2051.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1827.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1873.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3245.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1078.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2109.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3077.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2756.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/190.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3128.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2727.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/124.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2235.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1241.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1191.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1295.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2951.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1366.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3285.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3339.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2400.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/441.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2920.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/924.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2641.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/965.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1067.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1359.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/353.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/191.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3390.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/512.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3226.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2636.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/427.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/59.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2294.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1846.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2016.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2195.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2347.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2185.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1200.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/604.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1330.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/680.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2181.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2346.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1820.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1895.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1706.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/819.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2376.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1944.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/595.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/379.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1688.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2810.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1584.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2697.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1288.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1878.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2671.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2811.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3148.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3344.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3040.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3388.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3204.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/73.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3308.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/313.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1708.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2881.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1123.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2361.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2650.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/601.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3351.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1310.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1738.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1197.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3025.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/871.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/188.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/274.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2112.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1094.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1080.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/98.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/375.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/396.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1235.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3255.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/41.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2850.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1997.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2340.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2257.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1160.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2730.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/480.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/527.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1318.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3306.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/620.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1206.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2591.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2770.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2162.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2541.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3099.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1799.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/248.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1808.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/123.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2334.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/710.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1549.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/230.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1091.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2019.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1580.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/580.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/685.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/408.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1710.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3084.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1551.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1012.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1471.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/509.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/872.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1582.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1629.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2896.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/256.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1328.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1034.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1048.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1562.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2352.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1673.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1947.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2392.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3047.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/776.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/559.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/247.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1933.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/477.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/94.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/904.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2958.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/932.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1084.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1987.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2128.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3247.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/362.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2547.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1985.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1634.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/60.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3296.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/627.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1919.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3012.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2778.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/538.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3348.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/221.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/167.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/57.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1289.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2149.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3149.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/515.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/227.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1146.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1095.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/894.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/690.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1329.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2258.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/822.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2227.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/112.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1762.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/664.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/938.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/372.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1912.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2458.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/388.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3054.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/478.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/193.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/374.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/639.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2166.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/452.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1962.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/152.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1534.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/368.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1665.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1955.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2614.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2612.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2224.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1440.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3261.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1044.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2488.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1748.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1496.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/745.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/738.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2662.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2436.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2859.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1836.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/506.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1854.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2602.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3108.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1737.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2221.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1735.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2767.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1434.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/192.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2411.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/412.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1865.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2277.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3129.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3144.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3006.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1099.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1082.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3169.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2589.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2331.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3082.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/701.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2036.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/91.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1054.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1017.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/653.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3166.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1406.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/3341.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1649.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/9.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/705.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/101.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1963.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/1372.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2740.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/test/2077.jpg
# ...
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/vDTrWFNoFrY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/fSlcfo-lZOU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/4aKHSC2Kwdo.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/TwfErbNGREo.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/4Kll319owQ4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/wbPYQhouUXQ.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/HsEudhb2BhU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/NOgKlfAAT1Y.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/xGj4tPvs6OU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/o2rj53cS2vw.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/u7lr51Gr4d4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/DLzbvgIPUAs.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/4hrwys4KMc4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/2hTZj5FDnvM.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/mpQiPB3XxXo.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/8ZhGz_R7AkE.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/bwq26bIBMa0.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/egsdPYD-sdU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/gigeOMKhpWo.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/FLae-Qg_cQA.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/1tBcRlUHpak.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/4EBoccEPbuc.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/c03YplQdmU0.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/g0HYe7RImSE.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/ZW9_CrOaGo4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/FFEqvoJBVpg.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/Px4R4OtX1aE.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/ssQXDIw-Guk.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/AfqvVIHqV34.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/e1MJOQfP4TE.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/dgGeu-EgZe0.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/tE_G3w0yGmo.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/5LmRb9A7qaE.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/rq2HKH5KFMM.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/MsFxxqPyfGI.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/i49u6-fhsy0.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/4Phh2D_ilPE.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/gDDsbSNDIzs.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/phQDGanM220.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/isUJhI-UkdU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/_DncgV2egIg.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/46jo7hwHeZ0.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/uiqoTLaxH48.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/KHc3SBRTB9s.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/QMgZOVs8xVE.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/wxtVEzKDl9o.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/WV5BwlRbWDQ.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/U8iTPIvRwVI.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/8UR88Igc5O0.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/ESYHGtxE39c.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/zSKKWWz75KI.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/wXGOXqgOqYA.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/4moXEmA0whk.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/pFi4XH1N2bg.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/pnIJg9V4CCY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/D3kBUxJ-vBI.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/nlzfCBJvHxo.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/B1wTKw2tM4o.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/YZsMo03vEVM.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/uqxzi_ghjgc.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/9T5ROA2erDg.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/E6ktrBiYkkU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/zbWOkvasmv4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/vNyuYKkYBhs.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/1ktlQr_lDZ4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/_rV32JBnMOk.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/TTj0_FGfGbc.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/C2tf2PDYBJY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/Y-xwuDKtm2o.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/nSbQJrYu_GY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/yYub6yiBWXI.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/VoP6plzKqtQ.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/DkrWvyi0TBU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/ixGG6Bd6vNA.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/SDsqbBzLxg8.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/pJy9Cs4_kaQ.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/UiFAa2M6FVs.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/kX5A-7HKB5k.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/fUsTpUzOhFY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/rP_VYWM9sfM.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/BaWyxXZ6BKA.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/Km3jtGmBtJM.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/j1ByUYwiCvQ.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/GrjXKNJAAag.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/L9LoIKMVMuc.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/FaQStVB37wY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/mFmDYk-JT88.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/7sTymMk4enM.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/aks1-TjFvY4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/ixmxsw5HC_Q.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/5Kr5tV8qTZc.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/ejiwVj5Y75U.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/aeT2YKIcivE.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/H1dUoBXpC-c.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/G4WKdaFwv1I.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/GIGsm_PkaI4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/lcR3kshC9F4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/1DaSjG74-WU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/VclQn9k03b8.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/fG3h3i_A-i8.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/ljmUVrcTdWs.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/G3Pj6RwKZJs.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/d_3F1slEDVU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/AQM19qgqC2c.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/zmJ8D8K5ms4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/tHqcg3td3Pg.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/wrUjcJYsmyM.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/ATmOqUzJ_eU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/ts8QOuPmJ8Q.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/v3jTeCAovro.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/BCSNTcCT934.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/7AtySUCDFf8.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/m4vGXUYHxp4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/IvlyYeUF9Is.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/bQ8Wgei2Rio.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/eBBDRjhbVVA.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/1q02gJcL55Y.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/j4-kqFciNGY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/b6_G-PRlDwk.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/f8qJjD3240k.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/hOH3Y5Pi28g.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/IKwJIrWn_gU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/B3jxTh-HUr8.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/jKrTvY5SvQk.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/RZnwTKpeQHM.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/E_1-dbIWpqk.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/nKiFjv3LMWo.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/PghcPWLnB6k.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/CSQ5t9B91N4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/CdB6a0Cw5p4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/ah0wmYPMAQA.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/-MNDN2uDRrE.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/h6xPLkVWK50.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/0efFI61qTKU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/0-SznMCCun4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/cdb_AMRnYy0.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/CrkvqrINe8s.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/i8n8TlSqSv4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/aZRfChviB2c.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/7OOfNmZbk6Y.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/C5G7JhnhaDE.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/-ZfkmwkZxFI.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/p2F5yyF5yiw.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/cU8LzwmPTfc.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/P03BF8tlxUY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/lXacB8pCBvE.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/5qNfgngWpyw.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/wAXmF8rMg4c.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/7ZTworRr0Gk.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/2VK2OiwttbE.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/7FBSqclTmrg.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/00yUgUDQWMI.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/ND_XE7dP5jg.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/xZooInXQ4p0.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/vG6lK_njdbY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/2b5bzqhDd20.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/Nz5boFKeoEY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/ZEr2HrualtM.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/rdebPS8GEMM.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/Uh6en0tJ1vQ.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/fuxVFJb3P-s.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/llB-bZg46Y0.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/0MUSJoWaZvY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/vlOPFuHenQQ.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/9-I4Ttuf120.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/YH_6e6yIts8.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/4vLsldruVHI.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/N3XvOqcQsLY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/R3UKDPXc6HY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/0JtZW1m1tfY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/IwmAJHmch8c.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/ofoFzMb7tN0.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/7yDDFWT9CzU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/GglEvkYLoqI.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/HTCvkswrsWY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/qn0mDKrJXJ0.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/jizyi83ph20.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/4iWNfrOvuWU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/OqSmb3n0j8o.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/wks2BgxJ490.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/KvLC7ZWbhBU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/TmAmnIRrUK8.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/r0KxrUyCE04.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/BB4F8t7i5rI.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/kqRuvLf3aYI.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/RdHyCwPvppI.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/SLdmEy6KStQ.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/CH9TqmaD3Uw.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/HgA4DIfbhRs.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/MvdIr7E4OIw.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/1RtzHcfOnPA.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/IN6_9wnadbA.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/7mSH86O2qzA.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/8uUh5s3V1sI.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/q1-c9VgAcnc.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/PASxxeSVV6k.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/uXXGhjK_TUs.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/UGQuJp8tO7c.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/21BudJFEcHg.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/YE8t8BBTaGU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/mlO8d00AWzU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/btPrR6NQgI8.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/_EvBqTVYxt0.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/4nRDm2NGjtk.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/U4dq7PeyNrU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/1y198gYrQPM.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/YJ3BRsO9Enc.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/VPw7FWxo3Vw.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/ty_RrYtPX9o.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/7p78s0z2zT4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/rSkftK-phA4.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/8BDB6ZqU2WU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/0QjaRbbd0w0.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/6dDJ_GdLAQE.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/gkKG7OwvCXo.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/0-5pBANKLng.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/-LTKPehE7CY.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/kiH883cmBzU.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/9GWDxQ32UYE.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/VmL-qtwpTFQ.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/rdGZMVvOW3U.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/Z_9SPtAY2Po.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/IO8Mha5uMYA.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/XSxRPeCbSNw.jpg
# /kaggle/input/CSC_43M04_EP_challenge/dataset/train_val/XIgWBZVIt-A.jpg

# %% [markdown]
# Récupération des données et préparation à l'exploitation

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder

data_path = "/kaggle/input/CSC_43M04_EP_challenge/dataset"

train_df = pd.read_csv(f"{data_path}/train_val.csv")
test_df = pd.read_csv(f"{data_path}/test.csv")

# Texte
train_df["text"] = train_df["title"].fillna("") + " " + train_df["description"].fillna("")
vectorizer = TfidfVectorizer(max_features=512)
text_features = vectorizer.fit_transform(train_df["text"]).toarray()

# Catégorie
encoder = OneHotEncoder(sparse=False, handle_unknown="ignore")
channel_features = encoder.fit_transform(train_df[["channel"]])

# Année
year_features = train_df[["year"]].values

# Cible
train_df["views_log"] = np.log1p(train_df["views"])
y = train_df["views_log"].values

# Fusion des features texte, chaîne, année
meta_features = np.concatenate([
    text_features,          # TF-IDF features
    channel_features,       # One-hot encoding
    year_features           # Année brute
], axis=1)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Préparation du dataset

# %%
import torch
from torch.utils.data import Dataset
from PIL import Image
import torchvision.transforms as transforms
import numpy as np
import os

transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])


class YouTubeDataset(Dataset):
    def __init__(self, df, text_feat, channel_feat, year_feat, targets, data_path):
        self.df = df
        self.text_feat = text_feat
        self.channel_feat = channel_feat
        self.year_feat = year_feat
        self.targets = targets
        self.data_path = data_path

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_id = self.df.iloc[idx]["id"]
        img_path = os.path.join(self.data_path, "train_val", f"{img_id}.jpg")

        image = Image.open(img_path).convert("RGB")
        image = transform(image)

        meta_features = np.concatenate([
            self.text_feat[idx],
            self.channel_feat[idx],
            self.year_feat[idx]
        ])

        return image, torch.tensor(meta_features, dtype=torch.float32), torch.tensor(self.targets[idx], dtype=torch.float32)

# %% [markdown]
# Modèle simple 1)

# %%
import torch
import torch.nn as nn

class YouTubeModel(nn.Module):
    def __init__(self, meta_input_dim, image_size=128):
        super().__init__()

        # CNN to extract features from thumbnails
        self.cnn = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),     # (B,3,H,W) -> (B,32,H,W)
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(2),                                # -> (B,32,H/2,W/2)

            nn.Conv2d(32, 64, kernel_size=3, padding=1),    # -> (B,64,H/2,W/2)
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(2),                                # -> (B,64,H/4,W/4)

            nn.Conv2d(64, 128, kernel_size=3, padding=1),   # -> (B,128,H/4,W/4)
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1),
            nn.AdaptiveAvgPool2d((4, 4)),                   # -> (B,128,4,4)

            nn.Flatten()                                    # -> (B,128*4*4)
        )


        self.image_output_dim = 128 * 4 * 4

        # Final regressor that combines image + metadata
        self.fc = nn.Sequential(
            nn.Linear(self.image_output_dim + meta_input_dim, 512),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.3),
            nn.Linear(512, 128),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.2),
            nn.Linear(128, 1)
        )
        self.meta_norm = nn.LayerNorm(meta_input_dim)

    def forward(self, image, meta):
        img_feat = self.cnn(image)
        meta = self.meta_norm(meta)
        x = torch.cat([img_feat, meta], dim=1)
        return self.fc(x).squeeze(1)

# %% [markdown]
# Modèle simple 2

# %%
import torch
import torch.nn as nn

class YouTubeModel_upgrade1(nn.Module):
    def __init__(self, meta_input_dim, image_size=128):
        super().__init__()

        # CNN to extract features from thumbnails
        self.cnn = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),     # (B,3,H,W) -> (B,32,H,W)
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(2),                                # -> (B,32,H/2,W/2)

            nn.Conv2d(32, 64, kernel_size=3, padding=1),    # -> (B,64,H/2,W/2)
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(2),                                # -> (B,64,H/4,W/4)

            nn.Conv2d(64, 128, kernel_size=3, padding=1),   # -> (B,128,H/4,W/4)
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1),
            nn.AdaptiveAvgPool2d((4, 4)),                   # -> (B,128,4,4)

            nn.Flatten()                                    # -> (B,128*4*4)
        )


        self.image_output_dim = 128 * 4 * 4

        # Final regressor that combines image + metadata
        self.fc = nn.Sequential(
            nn.Linear(self.image_output_dim + 64, 512),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.3),
            nn.Linear(512, 128),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.2),
            nn.Linear(128, 1)
        )
        self.meta_mlp = nn.Sequential(
            nn.LayerNorm(meta_input_dim),
            nn.Linear(meta_input_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64)  # Tu peux ajuster 64 selon ta préférence
        )

    def forward(self, image, meta):
        img_feat = self.cnn(image)
        meta_feat = self.meta_mlp(meta)  
        x = torch.cat([img_feat, meta_feat], dim=1)
        return self.fc(x).squeeze(1)

# %% [markdown]
# Modèle simple 3)

# %%
import torch
import torch.nn as nn

class YouTubeModel_LiteAttention(nn.Module):
    def __init__(self, meta_input_dim, image_size=128, d_model=96, patch_size=16, nhead=2, num_layers=1):
        super().__init__()
        self.d_model = d_model

        self.patch_embed = nn.Conv2d(3, d_model, kernel_size=patch_size, stride=patch_size)
        num_patches = (image_size // patch_size) ** 2

        self.cls_token = nn.Parameter(torch.randn(1, 1, d_model))
        self.meta_token = nn.Sequential(
            nn.LayerNorm(meta_input_dim),
            nn.Linear(meta_input_dim, d_model),
            nn.ReLU(),
            nn.Linear(d_model, d_model)
        )

        self.pos_embed = nn.Parameter(torch.randn(1, num_patches + 2, d_model))  # [CLS] + [META]
        self.dropout = nn.Dropout(0.3)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=256,
            activation="gelu",
            batch_first=True,
            dropout=0.3
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        self.head = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.Linear(d_model, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 1)
        )

    def forward(self, image, meta):
        B = image.size(0)

        x = self.patch_embed(image)                # [B, D, H', W']
        x = x.flatten(2).transpose(1, 2)           # [B, N_patches, D]

        cls_token = self.cls_token.expand(B, 1, -1)
        meta_tok = self.meta_token(meta).unsqueeze(1)

        tokens = torch.cat([cls_token, meta_tok, x], dim=1)  # [B, N+2, D]
        tokens = self.dropout(tokens + self.pos_embed[:, :tokens.size(1)])

        x = self.transformer(tokens)
        return self.head(x[:, 0]).squeeze(1)  # Utilise le [CLS] token

# %% [markdown]
# Modèle simple 4)

# %%
import torch
import torch.nn as nn

class YouTubeModel_CNN_MetaAttention(nn.Module):
    def __init__(self, meta_input_dim, image_size=128):
        super().__init__()

        # --- 1. CNN image encoder ---
        self.cnn = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),  # 64x64
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((4, 4)),  # [B, 64, 4, 4]
            nn.Flatten()  # [B, 1024]
        )
        img_feat_dim = 64 * 4 * 4

        # --- 2. MLP metadata encoder ---
        self.meta_net = nn.Sequential(
            nn.LayerNorm(meta_input_dim),
            nn.Linear(meta_input_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 128)
        )

        # --- 3. Attention encoder (image + meta) ---
        self.attention_input_dim = img_feat_dim + 128

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=self.attention_input_dim,
            nhead=4,
            dim_feedforward=256,
            dropout=0.2,
            activation="gelu",
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=1)

        # --- 4. Head ---
        self.head = nn.Sequential(
            nn.LayerNorm(self.attention_input_dim),
            nn.Linear(self.attention_input_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1)
        )

    def forward(self, image, meta):
        img_feat = self.cnn(image)           # [B, 1024]
        meta_feat = self.meta_net(meta)      # [B, 128]

        # Fusion + attention
        combined = torch.cat([img_feat, meta_feat], dim=1).unsqueeze(1)  # [B, 1, D]
        attended = self.transformer(combined)[:, 0]                      # [B, D]

        return self.head(attended).squeeze(1)

# %% [markdown]
# Entrainement

# %%
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from torch.optim.lr_scheduler import ReduceLROnPlateau

X_train, X_val, idx_train, idx_val = train_test_split(
    np.arange(len(train_df)), np.arange(len(train_df)), test_size=0.1, random_state=42)

train_dataset = YouTubeDataset(train_df.iloc[idx_train], text_features[idx_train], channel_features[idx_train], year_features[idx_train], y[idx_train], data_path)
val_dataset = YouTubeDataset(train_df.iloc[idx_val], text_features[idx_val], channel_features[idx_val], year_features[idx_val], y[idx_val], data_path)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_1 = YouTubeModel(meta_input_dim=text_features.shape[1] + channel_features.shape[1] + 1).to(device)
model_2 = YouTubeModel_upgrade1(meta_input_dim=text_features.shape[1] + channel_features.shape[1] + 1).to(device)
model_3 = YouTubeModel_LiteAttention(
    meta_input_dim=text_features.shape[1] + channel_features.shape[1] + 1
).to(device)
model_4 = YouTubeModel_CNN_MetaAttention(
    meta_input_dim=text_features.shape[1] + channel_features.shape[1] + 1
).to(device)


#Choix du modèle ici
model = model_4






def entraine(premier_model):

    optimizer = torch.optim.Adam(premier_model.parameters(), lr=1e-3)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)
    loss_fn = nn.HuberLoss()
    
    from tqdm.notebook import tqdm  # barre pour Jupyter/Kaggle

    for epoch in range(4):
        premier_model.train()
        train_losses = []
        pbar = tqdm(train_loader, desc=f"Epoch {epoch+1} [train]")
        for images, metas, targets in pbar:
            images, metas, targets = images.to(device), metas.to(device), targets.to(device)
            preds = premier_model(images, metas)
            loss = loss_fn(preds, targets)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())
            pbar.set_postfix({"loss": np.mean(train_losses)})

        # Validation
        premier_model.eval()
        val_losses = []
        with torch.no_grad():
            for images, metas, targets in val_loader:
                images, metas, targets = images.to(device), metas.to(device), targets.to(device)
                preds = premier_model(images, metas)
                val_losses.append(loss_fn(preds, targets).item())
        scheduler.step(np.mean(val_losses))
        print(f" Epoch {epoch+1} done | Train Loss: {np.mean(train_losses):.4f} | Val Loss: {np.mean(val_losses):.4f}")

#Entrainement de tous les modèles.

for model in [model_1,model_2,model_3,model_4]:
    entraine(model)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 1 done | Train Loss: 1.5587 | Val Loss: 1.2596
# Epoch 2 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 2 done | Train Loss: 1.3576 | Val Loss: 1.1743
# Epoch 3 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 3 done | Train Loss: 1.3176 | Val Loss: 1.1691
# Epoch 4 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 4 done | Train Loss: 1.2804 | Val Loss: 1.1344
# Epoch 1 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 1 done | Train Loss: 1.5457 | Val Loss: 1.2239
# Epoch 2 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 2 done | Train Loss: 1.3701 | Val Loss: 1.1532
# Epoch 3 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 3 done | Train Loss: 1.3058 | Val Loss: 1.3916
# Epoch 4 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 4 done | Train Loss: 1.3028 | Val Loss: 1.3604
# Epoch 1 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 1 done | Train Loss: 1.6684 | Val Loss: 1.6860
# Epoch 2 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 2 done | Train Loss: 1.4181 | Val Loss: 1.5055
# Epoch 3 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 3 done | Train Loss: 1.4230 | Val Loss: 1.4358
# Epoch 4 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 4 done | Train Loss: 1.4182 | Val Loss: 1.3987
# Epoch 1 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 1 done | Train Loss: 1.5709 | Val Loss: 1.3782
# Epoch 2 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 2 done | Train Loss: 1.4939 | Val Loss: 1.5919
# Epoch 3 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 3 done | Train Loss: 1.4694 | Val Loss: 1.2892
# Epoch 4 [train]:   0%|          | 0/436 [00:00<?, ?it/s]
#  Epoch 4 done | Train Loss: 1.4406 | Val Loss: 1.3534

# %% [markdown]
# Validation du modèle

# %%
from tqdm import tqdm

test_df["text"] = test_df["title"].fillna("") + " " + test_df["description"].fillna("")

text_features_test = vectorizer.transform(test_df["text"]).toarray()
channel_features_test = encoder.transform(test_df[["channel"]])
year_features_test = test_df[["year"]].values



class YouTubeTestDataset(Dataset):
    def __init__(self, df, text_feat, channel_feat, year_feat, data_path):
        self.df = df
        self.text_feat = text_feat
        self.channel_feat = channel_feat
        self.year_feat = year_feat
        self.data_path = data_path

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_id = self.df.iloc[idx]["id"]
        img_path = os.path.join(self.data_path, "test", f"{img_id}.jpg")
        image = Image.open(img_path).convert("RGB")
        image = transform(image)

        meta = np.concatenate([
            self.text_feat[idx],
            self.channel_feat[idx],
            self.year_feat[idx]
        ])
        return image, torch.tensor(meta, dtype=torch.float32)



test_dataset = YouTubeTestDataset(test_df, text_features_test, channel_features_test, year_features_test, data_path)
test_loader = DataLoader(test_dataset, batch_size=64)

model.eval()
predictions = []

with torch.no_grad():
    for images, metas in tqdm(test_loader, desc="🔍 Predicting"):
        images, metas = images.to(device), metas.to(device)
        preds = model(images, metas)
        predictions.extend(preds.cpu().numpy())

views_pred = np.expm1(predictions).astype(int)

submission = pd.DataFrame({
    "ID": test_df["id"],
    "views": views_pred
})

submission.to_csv("/kaggle/working/submission.csv", index=False)
# Out:
# 🔍 Predicting: 100%|██████████| 54/54 [00:44<00:00,  1.21it/s]

# %% [markdown]
# Nombre de paramètres

# %%
for model in [model_1,model_2,model_3,model_4]:
    total_params = sum(p.numel() for p in model.parameters())
    print(f"Nombre total de paramètres : {total_params:,}")
# Out:
# Nombre total de paramètres : 1,495,903
# Nombre total de paramètres : 1,322,399
# Nombre total de paramètres : 244,319
# Nombre total de paramètres : 6,093,727
